# %% [markdown]
# <a href="https://colab.research.google.com/github/villeguits/Python_Exercises/blob/main/4_taller_POS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Ejercicio
#
# A continuación cargamos un texto correspondiente al capitulo 1 del libro Historia de dos ciudades de Charles Dikens:

# %%
# Por favor no sobreescriba o modifique esta celda
text1 = """
The Period

    It was the best of times,
    it was the worst of times,
    it was the age of wisdom,
    it was the age of foolishness,
    it was the epoch of belief,
    it was the epoch of incredulity,
    it was the season of Light,
    it was the season of Darkness,
    it was the spring of hope,
    it was the winter of despair,

we had everything before us, we had nothing before us, we were all going direct to Heaven,
we were all going direct the other way— in short, the period was so far like the present period,
that some of its noisiest authorities insisted on its being received, for good or for evil,
in the superlative degree of comparison only.

There were a king with a large jaw and a queen with a plain face, on the throne of England;
there were a king with a large jaw and a queen with a fair face, on the throne of France.
In both countries it was clearer than crystal to the lords of the State preserves of loaves and fishes,
that things in general were settled for ever.

It was the year of Our Lord one thousand seven hundred and seventy-five. Spiritual revelations were conceded to England at
that favoured period, as at this. Mrs. Southcott had recently attained her five-and-twentieth blessed birthday, of whom a
prophetic private in the Life Guards had heralded the sublime appearance by announcing that arrangements were made for
the swallowing up of London and Westminster. Even the Cock-lane ghost had been laid only a round dozen of years, after rapping
out its messages, as the spirits of this very year last past (supernaturally deficient in originality) rapped out theirs.
Mere messages in the earthly order of events had lately come to the English Crown and People, from a congress of British
subjects in America: which, strange to relate, have proved more important to the human race than any communications yet
received through any of the chickens of the Cock-lane brood.

France, less favoured on the whole as to matters spiritual than her sister of the shield and trident, rolled with exceeding smoothness down hill,
making paper money and spending it. Under the guidance of her Christian pastors, she entertained herself, besides, with such humane achievements
as sentencing a youth to have his hands cut off, his tongue torn out with pincers, and his body burned alive, because he had not kneeled down in
the rain to do honour to a dirty procession of monks which passed within his view, at a distance of some fifty or sixty yards. It is likely enough
that, rooted in the woods of France and Norway, there were growing trees, when that sufferer was put to death, already marked by the Woodman,
Fate, to come down and be sawn into boards, to make a certain movable framework with a sack and a knife in it, terrible in history.
It is likely enough that in the rough outhouses of some tillers of the heavy lands adjacent to Paris, there were sheltered from the weather
that very day, rude carts, bespattered with rustic mire, snuffed about by pigs, and roosted in by poultry, which the Farmer, Death, had already
set apart to be his tumbrils of the Revolution. But that Woodman and that Farmer, though they work unceasingly, work silently, and no one heard
them as they went about with muffled tread: the rather, forasmuch as to entertain any suspicion that they were awake, was to be atheistical and
traitorous.

In England, there was scarcely an amount of order and protection to justify much national boasting. Daring burglaries by armed men,
and highway robberies, took place in the capital itself every night; families were publicly cautioned not to go out of town without
removing their furniture to upholsterers' warehouses for security; the highwayman in the dark was a City tradesman in the light, and,
being recognised and challenged by his fellow-tradesman whom he stopped in his character of “the Captain,” gallantly shot him through
the head and rode away; the mail was waylaid by seven robbers, and the guard shot three dead, and then got shot dead himself by the other
four, “in consequence of the failure of his ammunition:” after which the mail was robbed in peace; that magnificent potentate,
the Lord Mayor of London, was made to stand and deliver on Turnham Green, by one highwayman, who despoiled the illustrious creature in
sight of all his retinue; prisoners in London gaols fought battles with their turnkeys, and the majesty of the law fired blunderbusses in
among them, loaded with rounds of shot and ball; thieves snipped off diamond crosses from the necks of noble lords at Court drawing-rooms;
musketeers went into St. Giles's, to search for contraband goods, and the mob fired on the musketeers, and the musketeers fired on the mob,
and nobody thought any of these occurrences much out of the common way. In the midst of them, the hangman, ever busy and ever worse
than useless, was in constant requisition; now, stringing up long rows of miscellaneous criminals; now, hanging a housebreaker on Saturday
who had been taken on Tuesday; now, burning people in the hand at Newgate by the dozen, and now burning pamphlets at the door of Westminster Hall;
to-day, taking the life of an atrocious murderer, and to-morrow of a wretched pilferer who had robbed a farmer's boy of sixpence.

All these things, and a thousand like them, came to pass in and close upon the dear old year one thousand seven hundred and seventy-five.
Environed by them, while the Woodman and the Farmer worked unheeded, those two of the large jaws, and those other two of the plain and the
fair faces, trod with stir enough, and carried their divine rights with a high hand. Thus did the year one thousand seven hundred and
seventy-five conduct their Greatnesses, and myriads of small creatures—the creatures of this chronicle among the rest—along the roads that
lay before them.
"""

# %% [markdown]
# # 1 Cargue spacy en la siguiente linea en `inglés`

# %%
import spacy
nlp = spacy.load('en_core_web_sm')

# %% [markdown]
# <details>
# <summary>
#     <font size="3" color="darkgreen"><b>Pista 1</b></font>
# </summary>
#
# * Recuerde importar spacy y luego cargarlo con la función `spacy.load`

# %% [markdown]
# # 2 Cree un objeto `doc` a partir de `nlp`

# %%
# Creamos el objeto Doc
doc = nlp(text1)

# %% [markdown]
# <details>
# <summary>
#     <font size="3" color="darkgreen"><b>Pista 1</b></font>
# </summary>
#
# * Recuerde utilizar el objeto `nlp` construido en el paso anterior

# %% [markdown]
# # 3 Imprima todo el texto tokenizado a partir de nlp

# %%
print(doc.text)
# Out:
# The Period
#
#     It was the best of times,
#     it was the worst of times,
#     it was the age of wisdom,
#     it was the age of foolishness,
#     it was the epoch of belief,
#     it was the epoch of incredulity,
#     it was the season of Light,
#     it was the season of Darkness,
#     it was the spring of hope,
#     it was the winter of despair,
#
# we had everything before us, we had nothing before us, we were all going direct to Heaven,
# we were all going direct the other way— in short, the period was so far like the present period,
# that some of its noisiest authorities insisted on its being received, for good or for evil,
# in the superlative degree of comparison only.
#
# There were a king with a large jaw and a queen with a plain face, on the throne of England;
# there were a king with a large jaw and a queen with a fair face, on the throne of France.
# In both countries it was clearer than crystal to the lords of the State preserves of loaves and fishes,
# that things in general were settled for ever.
#
# It was the year of Our Lord one thousand seven hundred and seventy-five. Spiritual revelations were conceded to England at
# that favoured period, as at this. Mrs. Southcott had recently attained her five-and-twentieth blessed birthday, of whom a
# prophetic private in the Life Guards had heralded the sublime appearance by announcing that arrangements were made for
# the swallowing up of London and Westminster. Even the Cock-lane ghost had been laid only a round dozen of years, after rapping
# out its messages, as the spirits of this very year last past (supernaturally deficient in originality) rapped out theirs.
# Mere messages in the earthly order of events had lately come to the English Crown and People, from a congress of British
# subjects in America: which, strange to relate, have proved more important to the human race than any communications yet
# received through any of the chickens of the Cock-lane brood.
#
# France, less favoured on the whole as to matters spiritual than her sister of the shield and trident, rolled with exceeding smoothness down hill,
# making paper money and spending it. Under the guidance of her Christian pastors, she entertained herself, besides, with such humane achievements
# as sentencing a youth to have his hands cut off, his tongue torn out with pincers, and his body burned alive, because he had not kneeled down in
# the rain to do honour to a dirty procession of monks which passed within his view, at a distance of some fifty or sixty yards. It is likely enough
# that, rooted in the woods of France and Norway, there were growing trees, when that sufferer was put to death, already marked by the Woodman,
# Fate, to come down and be sawn into boards, to make a certain movable framework with a sack and a knife in it, terrible in history.
# It is likely enough that in the rough outhouses of some tillers of the heavy lands adjacent to Paris, there were sheltered from the weather
# that very day, rude carts, bespattered with rustic mire, snuffed about by pigs, and roosted in by poultry, which the Farmer, Death, had already
# set apart to be his tumbrils of the Revolution. But that Woodman and that Farmer, though they work unceasingly, work silently, and no one heard
# them as they went about with muffled tread: the rather, forasmuch as to entertain any suspicion that they were awake, was to be atheistical and
# traitorous.
#
# In England, there was scarcely an amount of order and protection to justify much national boasting. Daring burglaries by armed men,
# and highway robberies, took place in the capital itself every night; families were publicly cautioned not to go out of town without
# removing their furniture to upholsterers' warehouses for security; the highwayman in the dark was a City tradesman in the light, and,
# being recognised and challenged by his fellow-tradesman whom he stopped in his character of “the Captain,” gallantly shot him through
# the head and rode away; the mail was waylaid by seven robbers, and the guard shot three dead, and then got shot dead himself by the other
# four, “in consequence of the failure of his ammunition:” after which the mail was robbed in peace; that magnificent potentate,
# the Lord Mayor of London, was made to stand and deliver on Turnham Green, by one highwayman, who despoiled the illustrious creature in
# sight of all his retinue; prisoners in London gaols fought battles with their turnkeys, and the majesty of the law fired blunderbusses in
# among them, loaded with rounds of shot and ball; thieves snipped off diamond crosses from the necks of noble lords at Court drawing-rooms;
# musketeers went into St. Giles's, to search for contraband goods, and the mob fired on the musketeers, and the musketeers fired on the mob,
# and nobody thought any of these occurrences much out of the common way. In the midst of them, the hangman, ever busy and ever worse
# than useless, was in constant requisition; now, stringing up long rows of miscellaneous criminals; now, hanging a housebreaker on Saturday
# who had been taken on Tuesday; now, burning people in the hand at Newgate by the dozen, and now burning pamphlets at the door of Westminster Hall;
# to-day, taking the life of an atrocious murderer, and to-morrow of a wretched pilferer who had robbed a farmer's boy of sixpence.
#
# All these things, and a thousand like them, came to pass in and close upon the dear old year one thousand seven hundred and seventy-five.
# Environed by them, while the Woodman and the Farmer worked unheeded, those two of the large jaws, and those other two of the plain and the
# fair faces, trod with stir enough, and carried their divine rights with a high hand. Thus did the year one thousand seven hundred and
# seventy-five conduct their Greatnesses, and myriads of small creatures—the creatures of this chronicle among the rest—along the roads that
# lay before them.

# %% [markdown]
# <details>
# <summary>
#     <font size="3" color="darkgreen"><b>Pista 1</b></font>
# </summary>
#
# * Utilice el atributo `text` del documento construido a partir de `nlp`

# %% [markdown]
# # 4 Utilice un f-string para imprimir una tabla con el texto del token, el pos_, el tag_, y la explicación. Obtenga los datos de los token con indice 4, 5, 10, y 12.

# %%
arreglo = [4,5,10,12]

for indice in arreglo:
    print(f'{doc[indice].text} {doc[indice].pos_} {doc[indice].tag_} {spacy.explain(doc[indice].tag_)}')
# Out:
# It PRON PRP pronoun, personal
# was AUX VBD verb, past tense
# , PUNCT , punctuation mark, comma
# it PRON PRP pronoun, personal

# %%
array = [4,5,10,12]

for indice in array:
    print(f'{doc[indice].text} {doc[indice].pos_} {doc[indice].tag_} {spacy.explain(doc[indice].tag_)}')
# Out:
# It PRON PRP pronoun, personal
# was AUX VBD verb, past tense
# , PUNCT , punctuation mark, comma
# it PRON PRP pronoun, personal

# %% [markdown]
# <details>
# <summary>
#     <font size="3" color="darkgreen"><b>Pista 1</b></font>
# </summary>
#
# * Utilice un f-string como se vio en el notebook de la sesion 1.

# %% [markdown]
# <details>
# <summary>
#     <font size="3" color="darkgreen"><b>Pista 2</b></font>
# </summary>
#
# * Cree un arreglo con las posiciones [4, 5, 10, 12]

# %% [markdown]
# <details>
# <summary>
#     <font size="3" color="darkgreen"><b>Pista 3</b></font>
# </summary>
#
# * Imprima cada uno de los textos iterando sobre el arreglo anterior y usando las propeidades text, pos_ y tag_

# %% [markdown]
# # 5 Seleccione todos los verbos

# %%
verbos = []
for token in doc:
  if token.tag_[0] == 'V':
    verbos.append(token.text)

# %%
print(verbos)
# Out:
# ['was', 'was', 'was', 'was', 'was', 'was', 'was', 'was', 'was', 'was', 'had', 'had', 'were', 'going', 'were', 'going', 'was', 'insisted', 'being', 'received', 'were', 'were', 'was', 'were', 'settled', 'was', 'were', 'conceded', 'favoured', 'had', 'attained', 'blessed', 'had', 'heralded', 'announcing', 'were', 'made', 'had', 'been', 'laid', 'rapped', 'had', 'come', 'relate', 'have', 'proved', 'received', 'rolled', 'exceeding', 'making', 'spending', 'entertained', 'sentencing', 'have', 'cut', 'torn', 'burned', 'had', 'kneeled', 'do', 'passed', 'is', 'rooted', 'were', 'growing', 'was', 'put', 'marked', 'come', 'be', 'sawn', 'make', 'is', 'were', 'sheltered', 'bespattered', 'snuffed', 'roosted', 'had', 'set', 'be', 'work', 'work', 'heard', 'went', 'entertain', 'were', 'was', 'be', 'was', 'justify', 'Daring', 'took', 'were', 'cautioned', 'go', 'removing', 'was', 'being', 'recognised', 'challenged', 'stopped', 'shot', 'rode', 'was', 'waylaid', 'shot', 'got', 'shot', 'was', 'robbed', 'was', 'made', 'stand', 'deliver', 'despoiled', 'fought', 'fired', 'loaded', 'snipped', 'went', 'search', 'fired', 'fired', 'thought', 'was', 'stringing', 'hanging', 'had', 'been', 'taken', 'burning', 'burning', 'taking', 'had', 'robbed', 'came', 'pass', 'close', 'Environed', 'worked', 'carried', 'did', 'lay']

# %% [markdown]
# <details>
# <summary>
#     <font size="3" color="darkgreen"><b>Pista 1</b></font>
# </summary>
#
# * Itere sobre los documentos y compruebe si el pos_ del token es un verbo

# %% [markdown]
# # 6 Cree con nltk una frecuencia de palabras para las primeras 30 palabras con los verbos y grafiquelo

# %%
import nltk
nltk.download("punkt")
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
from nltk import FreqDist

fdist = FreqDist(verbos)

# %%
fdist.plot(30, cumulative = False)

# %% [markdown]
# # 7 (Opcional: Avanzado) ¿Cuál son los verbos con dos aparaciones dentro del texto?

# %%
freq2 = [verbo for verbo, freq in fdist.items()  if freq == 2 ]

# %%
freq2
# Out:
# ['going',
#  'being',
#  'received',
#  'made',
#  'been',
#  'come',
#  'have',
#  'is',
#  'work',
#  'went',
#  'robbed',
#  'burning']

# %% [markdown]
# <details>
# <summary>
#     <font size="3" color="darkgreen"><b>Pista 1</b></font>
# </summary>
#
# * Utilice el método items() del objeto nltk.FreqDist

# %% [markdown]
# <details>
# <summary>
#     <font size="3" color="darkgreen"><b>Pista 2</b></font>
# </summary>
#
# * Itere sobre los items y compruebe cual tiene dos apariciones

# %% [markdown]
# # 8 Cuente las etiquetas POS

# %%
POS_counts = doc.count_by(spacy.attrs.POS)
POS_counts
# Out:
# {84: 82,
#  85: 171,
#  86: 35,
#  87: 55,
#  89: 45,
#  90: 154,
#  92: 211,
#  93: 28,
#  94: 19,
#  95: 52,
#  96: 54,
#  97: 148,
#  98: 24,
#  100: 89,
#  101: 1,
#  103: 58}

# %% [markdown]
# <details>
# <summary>
#     <font size="3" color="darkgreen"><b>Pista 1</b></font>
# </summary>
#
# * Utilice la función count_by del documento, pasandole como argumento spacy.attrs.POS

# %% [markdown]
# # 9 ¿Cuál es la etiqueta `pos` que más se encuentra dentro del texto? y ¿cuál es la etiqueta `pos` que menos se encuentra (exceptunado las que no aparecen)?

# %%
for k,v in sorted(POS_counts.items()):
    print(f'{k:{4}}. {doc.vocab[k].text:{6}}: {v}')

#La etiqueta que más se encuentra es NOUN noun y la que menos se encuentra es ADP
# Out:
#   84. ADJ   : 82
#   85. ADP   : 171
#   86. ADV   : 35
#   87. AUX   : 55
#   89. CCONJ : 45
#   90. DET   : 154
#   92. NOUN  : 211
#   93. NUM   : 28
#   94. PART  : 19
#   95. PRON  : 52
#   96. PROPN : 54
#   97. PUNCT : 148
#   98. SCONJ : 24
#  100. VERB  : 89
#  101. X     : 1
#  103. SPACE : 58

# %% [markdown]
# # 10 Cree una lista de frecuencias para todo el documento

# %%
freqdoc = FreqDist(map(lambda x: x.text, doc))

# %%
freqdoc.plot(cumulative = False)

# %%
freqdoc.plot(30 ,cumulative = False)

# %% [markdown]
# <details>
# <summary>
#     <font size="3" color="darkgreen"><b>Pista 1</b></font>
# </summary>
#
# * Utilice la función count_by y recorra los items

# %% [markdown]
# # 11 Cuente las etiquetas POS de grano fino

# %%
# Contar las etiquetas POS de grano fino
TAG_counts = doc.count_by(spacy.attrs.TAG)

for k,v in sorted(TAG_counts.items()):
    print(f'{k:20}  {doc.vocab[k].text:{3}}: {v}')
# Out:
#                   74  POS: 3
#   164681854541413346  RB : 34
#   272890857012483650  JJR: 2
#   783433942507015291  NNS: 71
#  1292078113972184607  IN : 183
#  1534113631682161808  VBG: 17
#  1895579588947004264  RBR: 2
#  2465883113906300949  -RRB-: 1
#  2593208677638477497  ,  : 94
#  3822385049556375858  VBN: 35
#  4062917326063685704  PRP$: 20
#  4808651922106831370  WP : 5
#  4969857429396651903  `` : 2
#  5595707737748328492  TO : 14
#  6860118812490040284  RP : 12
#  6893682062797376370  _SP: 58
#  7477624496606277342  PDT: 2
#  8214596291009089021  HYPH: 11
#  8427216679587749980  CD : 28
#  9188597074677201817  VBP: 2
# 10554686591937588953  JJ : 78
# 11233576250605462493  NNPS: 2
# 11532473245541075862  :  : 18
# 12646065887601541794  .  : 19
# 13656873538139661788  PRP: 39
# 13927759927860985106  VBZ: 2
# 14143520107006108953  '' : 2
# 14200088355797579614  VB : 18
# 14753207560692742245  JJS: 2
# 15267657372422890137  DT : 124
# 15308085513773655218  NN : 143
# 15361090031084224697  EX : 5
# 15401913388386482565  FW : 1
# 15794550382381185553  NNP: 52
# 17109001835818727656  VBD: 70
# 17111077179131903759  -LRB-: 1
# 17202369883303991778  WDT: 8
# 17524233984504158541  WRB: 1
# 17571114184892886314  CC : 45

# %% [markdown]
# <details>
# <summary>
#     <font size="3" color="darkgreen"><b>Pista 1</b></font>
# </summary>
#
# * Utilice count_by y luego recorra los items(). Utilice la función vocab para saber de cual POS se trata

# %% [markdown]
# # 12 Explique que quiere decir el número que se obtiene al recorrer los tag de spacy

# %% [markdown]
# Se refiere a los hash designados por spacy para los POS de grano fino que se identificaron dentro del corpus.

# %% [markdown]
# # 13 Visualice las etiquetas POS de las frases 3, 10, 30 y 33 con un ciclo

# %%
# Importamos la librería displaCy
from spacy import displacy

# %%
from nltk.tokenize import sent_tokenize

frases = sent_tokenize(text1)

# %%
arreglo2 = [3,10,30,33]

for indice in arreglo2:
    print(f'{doc[indice].text} {doc[indice].pos_} {doc[indice].head.text} {doc[indice].dep_} {spacy.explain(doc[indice].dep_)}')
# Out:
#      SPACE Period  None
# , PUNCT was punct punctuation
# the DET age det determiner
# foolishness NOUN of pobj object of preposition

# %% [markdown]
# <details>
# <summary>
#     <font size="3" color="darkgreen"><b>Pista 1</b></font>
# </summary>
#
# * Utilice la función count_by y recorra los items

# %% [markdown]
# # 14 Muestre las etiquetas POS de grano grueso para cada token de la oración con indice 3 e indice 30, además que las dependencias sintácticas:

# %%
arreglo3 = [3,30]

for indice in arreglo3:
    print(f'{doc[indice].text} {doc[indice].pos_} {doc[indice].head.text} {doc[indice].dep_} {spacy.explain(doc[indice].dep_)}')


# Visualizamos las dependencias sintácticas

displacy.render(doc, style='dep', jupyter=True, options={'distance': 110})
# Out:
#      SPACE Period  None
# the DET age det determiner
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="66c6d1795d314980a34757e1ce46c0ed-0" class="displacy" width="118520" height="1897.0" direction="ltr" style="max-width: none; height: 1897.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1807.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">
# </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1807.0">
#     <tspan class="displacy-word" fill="currentColor" x="160">The</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="160">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1807.0">
#     <tspan class="displacy-word" fill="currentColor" x="270">Period</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="270">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1807.0">
#     <tspan class="displacy-word" fill="currentColor" x="380">
#
#     </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="380">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1807.0">
#     <tspan class="displacy-word" fill="currentColor" x="490">It</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="490">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1807.0">
#     <tspan class="displacy-word" fill="currentColor" x="600">was</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="600">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1807.0">
#     <tspan class="displacy-word" fill="currentColor" x="710">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="710">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1807.0">
#     <tspan class="displacy-word" fill="currentColor" x="820">best</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="820">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1807.0">
#     <tspan class="displacy-word" fill="currentColor" x="930">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="930">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1807.0">
#     <tspan class="displacy-word" fill="currentColor" x="1040">times,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1040">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1807.0">
#     <tspan class="displacy-word" fill="currentColor" x="1150">
#     </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1150">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1807.0">
#     <tspan class="displacy-word" fill="currentColor" x="1260">it</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1260">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1807.0">
#     <tspan class="displacy-word" fill="currentColor" x="1370">was</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1370">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1807.0">
#     <tspan class="displacy-word" fill="currentColor" x="1480">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1480">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1807.0">
#     <tspan class="displacy-word" fill="currentColor" x="1590">worst</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1590">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1807.0">
#     <tspan class="displacy-word" fill="currentColor" x="1700">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1700">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1807.0">
#     <tspan class="displacy-word" fill="currentColor" x="1810">times,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1810">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1807.0">
#     <tspan class="displacy-word" fill="currentColor" x="1920">
#     </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1920">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1807.0">
#     <tspan class="displacy-word" fill="currentColor" x="2030">it</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2030">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1807.0">
#     <tspan class="displacy-word" fill="currentColor" x="2140">was</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2140">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1807.0">
#     <tspan class="displacy-word" fill="currentColor" x="2250">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2250">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1807.0">
#     <tspan class="displacy-word" fill="currentColor" x="2360">age</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2360">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1807.0">
#     <tspan class="displacy-word" fill="currentColor" x="2470">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2470">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1807.0">
#     <tspan class="displacy-word" fill="currentColor" x="2580">wisdom,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2580">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1807.0">
#     <tspan class="displacy-word" fill="currentColor" x="2690">
#     </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2690">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1807.0">
#     <tspan class="displacy-word" fill="currentColor" x="2800">it</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2800">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1807.0">
#     <tspan class="displacy-word" fill="currentColor" x="2910">was</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2910">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1807.0">
#     <tspan class="displacy-word" fill="currentColor" x="3020">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3020">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1807.0">
#     <tspan class="displacy-word" fill="currentColor" x="3130">age</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3130">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1807.0">
#     <tspan class="displacy-word" fill="currentColor" x="3240">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3240">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1807.0">
#     <tspan class="displacy-word" fill="currentColor" x="3350">foolishness,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x=

# %% [markdown]
# <details>
# <summary>
#     <font size="3" color="darkgreen"><b>Pista 1</b></font>
# </summary>
#
# * Construya una lista de las sentencias con la función list().

# %% [markdown]
# <details>
# <summary>
#     <font size="3" color="darkgreen"><b>Pista 2</b></font>
# </summary>
#
# * Construya una lista de las sentencias con la función list().

# %% [markdown]
# # POS en NLTK

# %% [markdown]
# # 15 Importemos `nltk`

# %%
import nltk

# %% [markdown]
# # 16 Importemos el `word_tokenize`

# %%
from nltk.tokenize import word_tokenize
# Descargamos los corpus y modelos más comunes
nltk.download("popular")
etiquetas = nltk.pos_tag(word_tokenize(text1))
print(etiquetas)
# Out:
# [nltk_data] Downloading collection 'popular'
# [nltk_data]    |
# [nltk_data]    | Downloading package cmudict to /root/nltk_data...
# [nltk_data]    |   Package cmudict is already up-to-date!
# [nltk_data]    | Downloading package gazetteers to /root/nltk_data...
# [nltk_data]    |   Package gazetteers is already up-to-date!
# [nltk_data]    | Downloading package genesis to /root/nltk_data...
# [nltk_data]    |   Package genesis is already up-to-date!
# [nltk_data]    | Downloading package gutenberg to /root/nltk_data...
# [nltk_data]    |   Package gutenberg is already up-to-date!
# [nltk_data]    | Downloading package inaugural to /root/nltk_data...
# [nltk_data]    |   Package inaugural is already up-to-date!
# [nltk_data]    | Downloading package movie_reviews to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package movie_reviews is already up-to-date!
# [nltk_data]    | Downloading package names to /root/nltk_data...
# [nltk_data]    |   Package names is already up-to-date!
# [nltk_data]    | Downloading package shakespeare to /root/nltk_data...
# [nltk_data]    |   Package shakespeare is already up-to-date!
# [nltk_data]    | Downloading package stopwords to /root/nltk_data...
# [nltk_data]    |   Package stopwords is already up-to-date!
# [nltk_data]    | Downloading package treebank to /root/nltk_data...
# [nltk_data]    |   Package treebank is already up-to-date!
# [nltk_data]    | Downloading package twitter_samples to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package twitter_samples is already up-to-date!
# [nltk_data]    | Downloading package omw to /root/nltk_data...
# [nltk_data]    |   Package omw is already up-to-date!
# [nltk_data]    | Downloading package wordnet to /root/nltk_data...
# [nltk_data]    |   Package wordnet is already up-to-date!
# [nltk_data]    | Downloading package wordnet_ic to /root/nltk_data...
# [nltk_data]    |   Package wordnet_ic is already up-to-date!
# [nltk_data]    | Downloading package words to /root/nltk_data...
# [nltk_data]    |   Package words is already up-to-date!
# [nltk_data]    | Downloading package maxent_ne_chunker to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package maxent_ne_chunker is already up-to-date!
# [nltk_data]    | Downloading package punkt to /root/nltk_data...
# [nltk_data]    |   Package punkt is already up-to-date!
# [nltk_data]    | Downloading package snowball_data to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package snowball_data is already up-to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger is already up-
# [nltk_data]    |       to-date!
# [nltk_data]    |
# [nltk_data]  Done downloading collection popular
# [('The', 'DT'), ('Period', 'NNP'), ('It', 'PRP'), ('was', 'VBD'), ('the', 'DT'), ('best', 'JJS'), ('of', 'IN'), ('times', 'NNS'), (',', ','), ('it', 'PRP'), ('was', 'VBD'), ('the', 'DT'), ('worst', 'JJS'), ('of', 'IN'), ('times', 'NNS'), (',', ','), ('it', 'PRP'), ('was', 'VBD'), ('the', 'DT'), ('age', 'NN'), ('of', 'IN'), ('wisdom', 'NN'), (',', ','), ('it', 'PRP'), ('was', 'VBD'), ('the', 'DT'), ('age', 'NN'), ('of', 'IN'), ('foolishness', 'NN'), (',', ','), ('it', 'PRP'), ('was', 'VBD'), ('the', 'DT'), ('epoch', 'NN'), ('of', 'IN'), ('belief', 'NN'), (',', ','), ('it', 'PRP'), ('was', 'VBD'), ('the', 'DT'), ('epoch', 'NN'), ('of', 'IN'), ('incredulity', 'NN'), (',', ','), ('it', 'PRP'), ('was', 'VBD'), ('the', 'DT'), ('season', 'NN'), ('of', 'IN'), ('Light', 'NNP'), (',', ','), ('it', 'PRP'), ('was', 'VBD'), ('the', 'DT'), ('season', 'NN'), ('of', 'IN'), ('Darkness', 'NNP'), (',', ','), ('it', 'PRP'), ('was', 'VBD'), ('the', 'DT'), ('spring', 'NN'), ('of', 'IN'), ('hope', 'NN'), (',', ','), ('it', 'PRP'), ('was', 'VBD'), ('the', 'DT'), ('winter', 'NN'), ('of', 'IN'), ('despair', 'NN'), (',', ','), ('we', 'PRP'), ('had', 'VBD'), ('everything', 'NN'), ('before', 'IN'), ('us', 'PRP'), (',', ','), ('we', 'PRP'), ('had', 'VBD'), ('nothing', 'NN'), ('before', 'IN'), ('us', 'PRP'), (',', ','), ('we', 'PRP'), ('were', 'VBD'), ('all', 'DT'), ('going', 'VBG'), ('direct', 'JJ'), ('to', 'TO'), ('Heaven', 'NNP'), (',', ','), ('we', 'PRP'), ('were', 'VBD'), ('all', 'DT'), ('going', 'VBG'), ('direct', 'JJ'), ('the', 'DT'), ('other', 'JJ'), ('way—', 'NN'), ('in', 'IN'), ('short', 'JJ'), (',', ','), ('the', 'DT'), ('period', 'NN'), ('was', 'VBD'), ('so', 'RB'), ('far', 'RB'), ('like', 'IN'), ('the', 'DT'), ('present', 'JJ'), ('period', 'NN'), (',', ','), ('that', 'IN'), ('some', 'DT'), ('of', 'IN'), ('its', 'PRP$'), ('noisiest', 'JJS'), ('authorities', 'NNS'), ('insisted', 'VBN'), ('on', 'IN'), ('its', 'PRP$'), ('being', 'VBG'), ('received', 'VBN'), (',', ','), ('for', 'IN'), ('good', 'JJ'), ('or', 'CC'), ('for', 'IN'), ('evil', 'JJ'), (',', ','), ('in', 'IN'), ('the', 'DT'), ('superlative', 'JJ'), ('degree', 'NN'), ('of', 'IN'), ('comparison', 'NN'), ('only', 'RB'), ('.', '.'), ('There', 'EX'), ('were', 'VBD'), ('a', 'DT'), ('king', 'NN'), ('with', 'IN'), ('a', 'DT'), ('large', 'JJ'), ('jaw', 'NN'), ('and', 'CC'), ('a', 'DT'), ('queen', 'NN'), ('with', 'IN'), ('a', 'DT'), ('plain', 'NN'), ('face', 'NN'), (',', ','), ('on', 'IN'), ('the', 'DT'), ('throne', 'NN'), ('of', 'IN'), ('England', 'NNP'), (';', ':'), ('there', 'EX'), ('were', 'VBD'), ('a', 'DT'), ('king', 'NN'), ('with', 'IN'), ('a', 'DT'), ('large', 'JJ'), ('jaw', 'NN'), ('and', 'CC'), ('a', 'DT'), ('queen', 'NN'), ('with', 'IN'), ('a', 'DT'), ('fair', 'JJ'), ('face', 'NN'), (',', ','), ('on', 'IN'), ('the', 'DT'), ('throne', 'NN'), ('of', 'IN'), ('France', 'NNP'), ('.', '.'), ('In', 'IN'), ('both', 'DT'), ('countries', 'NNS'), ('it', 'PRP'), ('was', 'VBD'), ('clearer', 'JJR'), ('than', 'IN'), ('crystal', 'NN'), ('to', 'TO'), ('the', 'DT'), ('lords', 'NNS'), ('of', 'IN'), ('the', 'DT'), ('State', 'NNP'), ('preserves', 'NNS'), ('of', 'IN'), ('loaves', 'NNS'), ('and', 'CC'), ('fishes', 'NNS'), (',', ','), ('that', 'WDT'), ('things', 'NNS'), ('in', 'IN'), ('general', 'JJ'), ('were', 'VBD'), ('settled', 'VBN'), ('for', 'IN'), ('ever', 'RB'), ('.', '.'), ('It', 'PRP'), ('was', 'VBD'), ('the', 'DT'), ('year', 'NN'), ('of', 'IN'), ('Our', 'PRP$'), ('Lord', 'NNP'), ('one', 'CD'), ('thousand', 'NN'), ('seven', 'CD'), ('hundred', 'CD'), ('and', 'CC'), ('seventy-five', 'JJ'), ('.', '.'), ('Spiritual', 'JJ'), ('revelations', 'NNS'), ('were', 'VBD'), ('conceded', 'VBN'), ('to', 'TO'), ('England', 'NNP'), ('at', 'IN'), ('that', 'DT'), ('favoured', 'JJ'), ('period', 'NN'), (',', ','), ('as', 'IN'), ('at', 'IN'), ('this', 'DT'), ('.', '.'), ('Mrs.', 'NNP'), ('Southcott', 'NNP'), ('had', 'VBD'), ('recently', 'RB'), ('attained', 'VBN'), ('her', 'PRP$'), ('five-and-twentieth', 'JJ'), ('blessed', 'JJ' ...

# %% [markdown]
# # 17 Importemos word tokenize

# %%
from nltk.tokenize import word_tokenize

# %% [markdown]
# # 18 Imprimamos las primeras 10 etiquetas de nltk

# %%
print(etiquetas[:10])
# Out:
# [('The', 'DT'), ('Period', 'NNP'), ('It', 'PRP'), ('was', 'VBD'), ('the', 'DT'), ('best', 'JJS'), ('of', 'IN'), ('times', 'NNS'), (',', ','), ('it', 'PRP')]

# %% [markdown]
# # 19 Imprimamos
